# %%
def is_valid(board, row, col, n):
    # Check row
    if 'Q' in board[row]:
        return False
    
    # Check column
    for i in range(row):
        if board[i][col] == 'Q':
            return False
    
    # Check upper left diagonal
    for i, j in zip(range(row, -1, -1), range(col, -1, -1)):
        if board[i][j] == 'Q':
            return False
    
    # Check upper right diagonal
    for i, j in zip(range(row, -1, -1), range(col, n)):
        if board[i][j] == 'Q':
            return False
    
    return True

def print_board(board):
    for row in board:
        print(" ".join(row))
    print()

def n_queens():
    while True:
        try:
            n = int(input("Enter the grid size (e.g., 6 for 6x6, 8 for 8x8): "))
            if n < 4:
                print("Grid size must be at least 4x4 for a valid solution.")
                continue
            break
        except ValueError:
            print("Please enter a valid integer.")
    
    board = [['.' for _ in range(n)] for _ in range(n)]
    placed_positions = set()
    queens_placed = 0
    
    print("Hint: Ensure each queen is placed in a unique row and column, avoiding any diagonal conflicts.")
    
    while queens_placed < n:
        try:
            row = int(input(f"Enter row position for Queen {queens_placed + 1} (0 to {n-1}): "))
            col = int(input(f"Enter column position for Queen {queens_placed + 1} (0 to {n-1}): "))
            
            if row < 0 or row >= n or col < 0 or col >= n:
                print("Position out of bounds. Try again.")
                continue
            
            if (row, col) in placed_positions:
                print("A queen is already placed here. Try again.")
                continue
            
            if not is_valid(board, row, col, n):
                print("Invalid position. This queen is under attack or violates row constraints. Try again.")
                continue
            
            board[row][col] = 'Q'
            placed_positions.add((row, col))
            queens_placed += 1
            print_board(board)
        
        except ValueError:
            print("Please enter valid integer values for row and column.")
    
    if queens_placed == n:
        print("All queens placed successfully in a valid configuration!")
        print_board(board)
    else:
        print("Failed to place all queens correctly.")

if __name__ == "__main__":
    n_queens()
# Out:
# Enter the grid size (e.g., 6 for 6x6, 8 for 8x8):  4
# Hint: Ensure each queen is placed in a unique row and column, avoiding any diagonal conflicts.
# Enter row position for Queen 1 (0 to 3):  0
# Enter column position for Queen 1 (0 to 3):  0
# Q . . .
# . . . .
# . . . .
# . . . .
# Enter row position for Queen 2 (0 to 3):  1
# Enter column position for Queen 2 (0 to 3):  2
# Q . . .
# . . Q .
# . . . .
# . . . .
# Enter row position for Queen 3 (0 to 3):  2
# Enter column position for Queen 3 (0 to 3):  1
# Invalid position. This queen is under attack or violates row constraints. Try again.
# Enter row position for Queen 3 (0 to 3):  2
# Enter column position for Queen 3 (0 to 3):  3
# Invalid position. This queen is under attack or violates row constraints. Try again.
# Enter row position for Queen 3 (0 to 3):  1
# Enter column position for Queen 3 (0 to 3):  3
# Invalid position. This queen is under attack or violates row constraints. Try again.
# Enter row position for Queen 3 (0 to 3):  2
# Enter column position for Queen 3 (0 to 3):  2
# Invalid position. This queen is under attack or violates row constraints. Try again.
# Enter row position for Queen 3 (0 to 3):  1
# Enter column position for Queen 3 (0 to 3):  2
# A queen is already placed here. Try again.
# Enter row position for Queen 3 (0 to 3):  1
# Enter column position for Queen 3 (0 to 3):  3
# Invalid position. This queen is under attack or violates row constraints. Try again.
# Enter row position for Queen 3 (0 to 3):  0
# Enter column position for Queen 3 (0 to 3):  0
# A queen is already placed here. Try again.
# Enter row position for Queen 3 (0 to 3):  0
# Enter column position for Queen 3 (0 to 3):  1
# Invalid position. This queen is under attack or violates row constraints. Try again.
# Enter row position for Queen 3 (0 to 3):  0
# Enter column position for Queen 3 (0 to 3):  2
# Invalid position. This queen is under attack or violates row constraints. Try again.
# Enter row position for Queen 3 (0 to 3):  0
# Enter column position for Queen 3 (0 to 3):  3
# Invalid position. This queen is under attack or violates row constraints. Try again.
# Enter row position for Queen 3 (0 to 3):  1
# Enter column position for Queen 3 (0 to 3):  1
# Invalid position. This queen is under attack or violates row constraints. Try again.
# Enter row position for Queen 3 (0 to 3):  1
# Enter column position for Queen 3 (0 to 3):  2
# A queen is already placed here. Try again.
# Enter row position for Queen 3 (0 to 3):  1
# Enter column position for Queen 3 (0 to 3):  3
# Invalid position. This queen is under attack or violates row constraints. Try again.
# Enter row position for Queen 3 (0 to 3):  2
# Enter column position for Queen 3 (0 to 3):  1
# Invalid position. This queen is under attack or violates row constraints. Try again.
# Enter row position for Queen 3 (0 to 3):  2
# Enter column position for Queen 3 (0 to 3):  2
# Invalid position. This queen is under attack or violates row constraints. Try again.
# Enter row position for Queen 3 (0 to 3):  2
# Enter column position for Queen 3 (0 to 3):  3
# Invalid position. This queen is under attack or violates row constraints. Try again.
# Enter row position for Queen 3 (0 to 3):  3
# Enter column position for Queen 3 (0 to 3):  0
# Invalid position. This queen is under attack or violates row constraints. Try again.
# Enter row position for Queen 3 (0 to 3):  3
# Enter column position for Queen 3 (0 to 3):  1
# Q . . .
# . . Q .
# . . . .
# . Q . .
# Enter row position for Queen 4 (0 to 3):  3
# Enter column position for Queen 4 (0 to 3):  2
# Invalid position. This queen is under attack or violates row constraints. Try again.
# Enter row position for Queen 4 (0 to 3):  3
# Enter column position for Queen 4 (0 to 3):  3
# Invalid position. This queen is under attack or violates row constraints. Try again.

# %%
def is_valid(board, row, col, n):
    # Check column
    for i in range(row):
        if board[i][col] == 'Q':
            return False
    
    # Check upper left diagonal
    for i, j in zip(range(row, -1, -1), range(col, -1, -1)):
        if board[i][j] == 'Q':
            return False
    
    # Check upper right diagonal
    for i, j in zip(range(row, -1, -1), range(col, n)):
        if board[i][j] == 'Q':
            return False
    
    return True

def print_board(board):
    for row in board:
        print(" ".join(row))
    print()

def n_queens():
    while True:
        try:
            n = int(input("Enter the grid size (e.g., 6 for 6x6, 8 for 8x8): "))
            if n < 4:
                print("Grid size must be at least 4x4 for a valid solution.")
                continue
            break
        except ValueError:
            print("Please enter a valid integer.")
    
    board = [['.' for _ in range(n)] for _ in range(n)]
    placed_positions = set()
    rows_used = set()
    queens_placed = 0
    
    print("Hint: Ensure each queen is placed in a unique row and column, avoiding any diagonal conflicts.")
    
    while queens_placed < n:
        try:
            row = int(input(f"Enter row position for Queen {queens_placed + 1} (0 to {n-1}): "))
            col = int(input(f"Enter column position for Queen {queens_placed + 1} (0 to {n-1}): "))
            
            if row < 0 or row >= n or col < 0 or col >= n:
                print("Position out of bounds. Try again.")
                continue
            
            if row in rows_used:
                print("Each row can have only one queen. Try again.")
                continue
            
            if (row, col) in placed_positions:
                print("A queen is already placed here. Try again.")
                continue
            
            if not is_valid(board, row, col, n):
                print("Invalid position. This queen is under attack. Try again.")
                continue
            
            board[row][col] = 'Q'
            placed_positions.add((row, col))
            rows_used.add(row)
            queens_placed += 1
            print_board(board)
        
        except ValueError:
            print("Please enter valid integer values for row and column.")
    
    if queens_placed == n:
        print("All queens placed successfully in a valid configuration!")
        print_board(board)
    else:
        print("Failed to place all queens correctly.")

if __name__ == "__main__":
    n_queens()
# Out:
# Enter the grid size (e.g., 6 for 6x6, 8 for 8x8):  6
# Hint: Ensure each queen is placed in a unique row and column, avoiding any diagonal conflicts.
# Enter row position for Queen 1 (0 to 5):  0
# Enter column position for Queen 1 (0 to 5):  3
# . . . Q . .
# . . . . . .
# . . . . . .
# . . . . . .
# . . . . . .
# . . . . . .
# Enter row position for Queen 2 (0 to 5):  1
# Enter column position for Queen 2 (0 to 5):  0
# . . . Q . .
# Q . . . . .
# . . . . . .
# . . . . . .
# . . . . . .
# . . . . . .
# Enter row position for Queen 3 (0 to 5):  2
# Enter column position for Queen 3 (0 to 5):  4
# . . . Q . .
# Q . . . . .
# . . . . Q .
# . . . . . .
# . . . . . .
# . . . . . .
# Enter row position for Queen 4 (0 to 5):  3
# Enter column position for Queen 4 (0 to 5):  2
# Invalid position. This queen is under attack. Try again.
# Enter row position for Queen 4 (0 to 5):  4
# Enter column position for Queen 4 (0 to 5):  1
# . . . Q . .
# Q . . . . .
# . . . . Q .
# . . . . . .
# . Q . . . .
# . . . . . .
